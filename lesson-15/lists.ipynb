# %%
l1 = [1, 2, 3, 4]

# %%
[i + 2 for i in l1]
# Out:
# [3, 4, 5, 6]

# %%
l2 = [
    [1, 2, 3],
    [4, 5, 6]
]
l2
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
[[j + 2 for j in i] for i in l2]
# Out:
# [[3, 4, 5], [6, 7, 8]]

# %%
l3 = [
    [1, 2, 3],
    [4, 5]
]

# %%
l3
# Out:
# [[1, 2, 3], [4, 5]]
